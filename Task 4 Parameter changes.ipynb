# %% [markdown]
# ### CM4603 – Coursework 2 (Individual)
# #### March 2025
#
# Name  : < Pooja Illangarathne > |
# RGU ID: < 2117529 >

# %%
from google.colab import drive
import pandas as pd
import os
import json
import re


drive.mount('/content/drive')  # Mounting Google Drive
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Answer to Task 4

# %%
# !pip install git+https://github.com/huggingface/transformers@v4.49.0-Gemma-3
# Out:
# Collecting git+https://github.com/huggingface/transformers@v4.49.0-Gemma-3
#   Cloning https://github.com/huggingface/transformers (to revision v4.49.0-Gemma-3) to /tmp/pip-req-build-nmo94uan
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-nmo94uan
#   Running command git checkout -q 1c0f782fe5f983727ff245c4c1b3906f9b99eec2
#   Resolved https://github.com/huggingface/transformers to commit 1c0f782fe5f983727ff245c4c1b3906f9b99eec2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (2025.1.31)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.50.0.dev0-py3-none-any.whl size=10936429 sha256=5970d791c4bb9795e222f54263c68dd094043d1254261bc6e4a9678039851da9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rlf9dfm0/wheels/53/15/d5/d63b866c641d8863f9cd29a4cc7a5efc38476c3aae8247c195
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.49.0
#     Uninstalling transformers-4.49.0:
#       Successfully uninstalled transformers-4.49.0
# Successfully installed transformers-4.50.0.dev0

# %%
# !pip install -U transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
import os
import numpy as np
import sentencepiece as spm
from gensim.models import FastText
from sklearn.neighbors import NearestNeighbors
import google.generativeai as genai
from google.colab import userdata

# %% [markdown]
# _The implementation integrates FastText embeddings, SentencePiece BPE tokenization, and the Gemini API to enable a retrieval-augmented generation (RAG) system for answering Sinhala-language questions related to the Sri Lankan Constitution. Initially, the Gemini API key is retrieved and configured to interact with Google's language model. The FastText word embeddings and SentencePiece BPE tokenizer are then loaded to handle text processing. The Sri Lankan Constitution is read and stored in a list of passages, with each passage's embedding precomputed using FastText. A nearest neighbor index (cosine similarity) is built to retrieve relevant passages when a user asks a question._
#
# _For context retrieval, the input query is converted into an embedding vector and the top three most similar passages are fetched using the nearest neighbors algorithm. The Gemini model is then used in two modes: (1) Answering questions without RAG, where the model directly generates a response based on the question alone, and (2) Answering with RAG, where the retrieved passages are appended to the query to provide more contextually relevant answers._

# %%
# Retrieve and configure the Gemini API key from Colab secrets
GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("GOOGLE_API_KEY not found. Please set it in Colab secrets.")
genai.configure(api_key=GOOGLE_API_KEY)

# Loading FastText and SentencePiece models
FASTTEXT_MODEL_PATH = "fasttext_sinhala_bpe.model"
BPE_MODEL_PATH = "sinhala_spm_bpe.model"
CONSTITUTION_PATH = "/content/drive/MyDrive/Sri Lanka Constitution-Sinhala.txt"

ft_model = FastText.load(FASTTEXT_MODEL_PATH)
sp = spm.SentencePieceProcessor(model_file=BPE_MODEL_PATH)

# Loading Constitution passages
with open(CONSTITUTION_PATH, "r", encoding="utf-8") as f:
    passages = [line.strip() for line in f if line.strip()]

# Computing averaged FastText embedding using BPE tokens
def get_embedding(text):
    tokens = sp.encode(text, out_type=str)
    valid_vectors = [ft_model.wv[t] for t in tokens if t in ft_model.wv.key_to_index]
    return np.mean(valid_vectors, axis=0) if valid_vectors else np.zeros(ft_model.vector_size)

# Precomputing passage embeddings and build a nearest neighbor index (cosine similarity)
passage_embeddings = np.array([get_embedding(p) for p in passages])
nn = NearestNeighbors(n_neighbors=3, metric="cosine")  # Retrieving top 3 passages
nn.fit(passage_embeddings)

# Retrieving context from the Constitution based on the question
def retrieve_context(question):
    query_emb = get_embedding(question).reshape(1, -1)
    distances, indices = nn.kneighbors(query_emb)
    return " ".join([passages[i] for i in indices[0]])

# Initializing the Gemini model
model = genai.GenerativeModel("gemini-1.5-flash")

# Generate an answer using the Gemini API
def generate_answer(prompt, max_tokens=300):
    response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            max_output_tokens=max_tokens,
            temperature=0.0
        )
    )
    return response.text

# Answer without RAG: Direct generation without context
def answer_without_rag(question):
    prompt = f"Q: {question}\nA:"
    return generate_answer(prompt)

# Answer with RAG: Combine retrieved context with the question
def answer_with_rag(question):
    context = retrieve_context(question)
    print("Retrieved Context:", context)
    prompt = (
        f"Instructions: Use the provided context to answer the question accurately and completely in Sinhala. "
        f"Include specific references to articles or sections of the Sri Lankan Constitution when relevant. "
        f"If the context is insufficient or irrelevant, use your general knowledge to provide a correct answer.\n"
        f"Context: {context}\n"
        f"Q: {question}\n"
        f"A:"
    )
    return generate_answer(prompt)

# Sample questions for testing
sample_questions = [
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?",
    "ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?",
    "ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?",
    "Is Tokyo the capital city of Japan ?",
    "What are the powers of the President of Sri Lanka?",
    "ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?"
]

# Test both approaches
print("=== Answers WITHOUT RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_without_rag(q))
    print("====================================\n")

print("=== Answers WITH RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_with_rag(q))
    print("====================================\n")
# Out:
# === Answers WITHOUT RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# A: ඔව්, ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අග්‍රාමාත්‍යවරයාය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලය ඇත, නමුත් එම බලය සීමා සහිතය.  ව්‍යවස්ථාවේ 34(1) වගන්තියට අනුව, ජනාධිපතිවරයාට ඕනෑම චෝදනාවකට හෝ වරදකට සමාව ලබාදිය හැකිය.  කෙසේ වුවද, මෙම බලය සම්පූර්ණයෙන්ම අසීමිත නොවේ.
#
# විශේෂයෙන්ම, ජනාධිපතිවරයාට පහත සඳහන් අවස්ථාවලදී සමාව ලබාදිය නොහැක:
#
# * **මහජන නියෝජිතයින්ගේ හෝ රාජ්‍ය නිලධාරීන්ගේ
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව රටේ ජාතික භාෂා දෙකක් තිබේ: **සිංහල** සහ **தமிழ் (தமிழ்)**.
#
# ====================================
#
# === Answers WITH RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# Retrieved Context: (2) පාර්ලිමේන්තුව විසින් ආණ්ඩුවේ ප්‍රතිපත්ති ප්‍රකාශය හෝ විසර්ජන පනත් කෙටුම්පත හෝ ප්‍රතික්ෂේප කළහොත් එවිට ද, ආණ්ඩුව කෙරෙහි විශ්වාසභංග යෝජනාවක් සම්මත කළහොත් එවිට ද, අමාත්‍ය මණ්ඩලය විසිරෙන්නේ ය. එසේ වූ විට 70 වන ව්‍යවස්ථාව යටතේ ස්වකීය බලතල ක්‍රියාත්මක කරමින් ජනාධිපතිවරයා විසින් පාර්ලිමේන්තුව විසුරුවා හරිනු ලැබුවහොත් මිස, ජනාධිපතිවරයා විසින් 43 වන, 44 වන, 45 වන සහ 46 වන ව්‍යවස්ථා අනුව අග්‍රාමාත්‍යවරය�
ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධාන වලට අනුකුලව යම් කාරණයක් සම්බන්ධයෙන් මුළු ශ්‍රී ලංකාව ම හෝ එහි යම් කොටසක් සඳහා නීති සැදීමට (මේ පරිච්ඡේදය ඇතුළුව) ආණ්ඩුක්‍රම ව්‍යවස්ථාවෙන් පාර්ලිමේන්තුවට පැවරී ඇති බලතල හීන කරන්නාක් සේ කියවා තේරුම් ගැනීම හෝ නොකළ යුත්තේ ය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 33(10) වගන්තියේ සඳහන් වන්නේ, ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධානවලට අනුකූලව යම් කාරණයක් සම්බන්ධයෙන් මුළු ශ්‍රී ලංකාව හෝ එහි යම් කොටසක් සඳහා නීති සැදීමට ආණ්ඩුක්‍රම ව්‍යවස්ථාවෙන් පාර්ලිමේන්තුවට පැවරී ඇති බලතල හීන කරන ලෙස කිසිවක් තේරුම් ගත යුතු නොවන බවයි.  මෙම වගන්තියෙන් ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලයක් ලබාදී ඇති
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# Retrieved Context: මේ ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ (ඉ) ඡේදයේ සඳහන් තැනැත්තන් පස්දෙනා නම් කිරීමේ දී, අවස්ථාවෝචිත පරිදි, අග්‍රාමාත්‍යවරයා, කථානායකවරයා සහ විරුද්ධ පක්ෂයේ නායකවරයා හෝ පාර්ලිමේන්තු මන්ත්‍රීවරයන් විසින් වෘත්තීය සහ සමාජයීය . විවිධත්වය ඇතුළුව ශ්‍රී ලාංකීය සමාජයේ බහුත්ත්ව ලක්ෂණය සභාවෙන් පිළිබිඹු වන බව සහතික කරනු ලැබිය යුත්තේ ය. (3) පරිපාලන භාෂාව වශයෙන් දෙමළ භාෂාව භාවිත කරනු ලබන යම් ප්‍රදේශයක, ස්වකීය නිල තත්ත්වයෙන් ක්‍රියා කරන නිලධරයකු නොවන යම් තැනැත්තකු මේ ව්‍යවස්ථාවේ (2) වන අනුව්‍යවස්ථාවේ (අ), (ආ) සහ (ඇ) ඡේදවල සඳහන් අයිතිවාසිකම් සහ සේවාවන් සිංහල භාෂාවෙන් හෝ ඉංග්‍රීසි භාෂාවෙන් ක්‍රියාත්මක කරවා ගැනීමට සහ ලබා ගැනීමට හිමිකම් ලැබිය යුත්තේ ය. 84. (1) ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයක් සංශෝධනය කිරීම සඳහා හෝ ආණ්ඩුක්‍රම ව්‍යවස්ථාව පරිච්ඡින්න කොට ප්‍රතියෝජනය කිරීම සඳහා හෝ නොවන, එහෙත් ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයකට අනනුකූල වූ පනත් කෙටුම්පතක්, 82 වන ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ හෝ (2) වන අනුව්‍යවස්ථාවේ හෝ නියමයන්ට අනුකූලව ක්‍රියා නොකොට පාර්ලිමේන්තුවේ න්‍යාය පත්‍රයට ඇතුළත් කළ හැක්කේය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ ඒ ගැන සෘජුවම සඳහන් වන්නේ නැත.  කෙසේ වුවද,  ලබාදී ඇති උපුටා ගැනීම්වලින් හෝ ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ  වෙනත් වගන්තිවලින් හෝ ජාතික භාෂා ලෙස සිංහල හා දෙමළ භාෂා දෙකම හඳුනාගත හැකිය.  විශේෂයෙන්ම, ලබාදී ඇති තොරතුරුවලින් පෙනී යන්නේ දෙමළ භාෂාව භාවිතා කරන ප්‍රදේශවල යම් යම් නිල කටයුතු සිංහල හෝ ඉංග්‍රීසි භාෂාවෙන් සිදු
# ====================================

# %%
# Retrieve and configure the Gemini API key from Colab secrets
GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("GOOGLE_API_KEY not found. Please set it in Colab secrets.")
genai.configure(api_key=GOOGLE_API_KEY)

# Loading FastText and SentencePiece models
FASTTEXT_MODEL_PATH = "fasttext_sinhala_bpe.model"
BPE_MODEL_PATH = "sinhala_spm_bpe.model"
CONSTITUTION_PATH = "/content/drive/MyDrive/Sri Lanka Constitution-Sinhala.txt"

ft_model = FastText.load(FASTTEXT_MODEL_PATH)
sp = spm.SentencePieceProcessor(model_file=BPE_MODEL_PATH)

# Loading Constitution passages
with open(CONSTITUTION_PATH, "r", encoding="utf-8") as f:
    passages = [line.strip() for line in f if line.strip()]

# Computing averaged FastText embedding using BPE tokens
def get_embedding(text):
    tokens = sp.encode(text, out_type=str)
    valid_vectors = [ft_model.wv[t] for t in tokens if t in ft_model.wv.key_to_index]
    return np.mean(valid_vectors, axis=0) if valid_vectors else np.zeros(ft_model.vector_size)

# Precomputing passage embeddings and build a nearest neighbor index (cosine similarity)
passage_embeddings = np.array([get_embedding(p) for p in passages])
nn = NearestNeighbors(n_neighbors=3, metric="cosine")  # Retrieving top 3 passages
nn.fit(passage_embeddings)

# Retrieving context from the Constitution based on the question
def retrieve_context(question):
    query_emb = get_embedding(question).reshape(1, -1)
    distances, indices = nn.kneighbors(query_emb)
    return " ".join([passages[i] for i in indices[0]])

# Initializing the Gemini model
model = genai.GenerativeModel("gemini-1.5-flash")

# Generate an answer using the Gemini API
def generate_answer(prompt, max_tokens=300):
    response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            max_output_tokens=max_tokens,
            temperature=0.0
        )
    )
    return response.text

# Answer without RAG: Direct generation without context
def answer_without_rag(question):
    prompt = f"Q: {question}\nA:"
    return generate_answer(prompt)

# Answer with RAG: Combine retrieved context with the question
def answer_with_rag(question):
    context = retrieve_context(question)
    print("Retrieved Context:", context)
    prompt = (
        f"Instructions: Use the provided context to answer the question accurately and completely in Sinhala. "
        f"Include specific references to articles or sections of the Sri Lankan Constitution when relevant. "
        f"If the context is insufficient or irrelevant, use your general knowledge to provide a correct answer.\n"
        f"Context: {context}\n"
        f"Q: {question}\n"
        f"A:"
    )
    return generate_answer(prompt)

# Sample questions for testing
sample_questions = [
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?",
    "ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?",
    "ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?",
    "Is Tokyo the capital city of Japan ?",
    "What are the powers of the President of Sri Lanka?",
    "ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?"
]

# Test both approaches
print("=== Answers WITHOUT RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_without_rag(q))
    print("====================================\n")

print("=== Answers WITH RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_with_rag(q))
    print("====================================\n")
# Out:
# === Answers WITHOUT RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# A: ඔව්, ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අග්‍රාමාත්‍යවරයාය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලය ඇත, නමුත් එම බලය සීමා සහිතය.  ව්‍යවස්ථාවේ 34(1) වගන්තියට අනුව, ජනාධිපතිවරයාට ඕනෑම චෝදනාවකට හෝ වරදකට සමාව ලබාදිය හැකිය.  කෙසේ වුවද, මෙම බලය සම්පූර්ණයෙන්ම අසීමිත නොවේ.
#
# විශේෂයෙන්ම, ජනාධිපතිවරයාට පහත සඳහන් අවස්ථාවලදී සමාව ලබාදිය නොහැක:
#
# * **මහජන නියෝජිතයින්ගේ හෝ රාජ්‍ය නිලධාරීන්ගේ
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව රටේ ජාතික භාෂා දෙකක් තිබේ: **සිංහල** සහ **தமிழ் (தமிழ்)**.
#
# ====================================
#
# Q: ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?
# A: ඕස්ට්‍රේලියාවේ අගනුවර **කැන්බරා** ය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?
# A: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ හතර ශ්‍රී ලංකාවේ ඓතිහාසික රාජධානි හතර නියෝජනය කරයි. ඒවා නම්:
#
# * **අනුරාධපුර**
# * **පොළොන්නරුව**
# * **කුරුණෑගල**
# * **කොට්ටේ**
#
# මෙම රාජධානි හතර ශ්‍රී ලංකාවේ ඓතිහාසික හා සංස්කෘතික උරුමයේ වැදගත් අංග වේ.
#
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# A: Yes, Tokyo is the capital city of Japan.
#
# ====================================
#
# Q: What are the powers of the President of Sri Lanka?
# A: The President of Sri Lanka holds significant power, acting as both head of state and head of government.  Their powers are extensive and encompass various aspects of governance, though they are subject to checks and balances (though these have been weakened in recent years).  Key powers include:
#
# **Executive Powers:**
#
# * **Appointing Power:**  The President appoints the Prime Minister (usually the leader of the majority party in Parliament), other ministers, judges of the Supreme Court and other superior courts, and high-ranking officials in the civil service and armed forces.
# * **Legislative Powers:**  While Parliament makes laws, the President has significant influence. They can summon, prorogue, and dissolve Parliament.  They can also certify bills as being urgent, allowing them to bypass certain parliamentary procedures.  They can also refuse assent to bills passed by Parliament, effectively vetoing them.
# * **Executive Orders:** The President can issue executive orders that have the force of law, though these are subject to judicial review.
# * **Emergency Powers:**  The President can declare a state of emergency, granting them extensive powers to suspend fundamental rights and detain individuals without trial.  This power has been used controversially in the past.
# * **Commander-in-Chief:** The President is the Commander-in-Chief of the armed forces.
# * **Pardon and Reprieve:** The President has the power to grant pardons, reprieves, and commutations of sentences.
#
#
# **Other Powers:**
#
#
# ====================================
#
# Q: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?
# A: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාට බහුල බලතල ඇති අතර ඒවා ප්‍රධාන වශයෙන් කාණ්ඩ තුනකට බෙදිය හැකිය:
#
# **1. විධායක බලතල:**
#
# * **රජයේ ප්‍රධානියා:** ජනාධිපතිවරයා රජයේ ප්‍රධානියා වන අතර, රටේ පරිපාලනය හා ආණ්ඩුවේ කටයුතු භාරව සිටී.
# * **ඇමති මණ්ඩලය පත් කිරීම:** ජනාධිපතිවරයා ඇමති මණ්ඩලය පත් කරන අතර, ඔවුන්ගේ කටයුතු පිළිබඳව අධීක්ෂණය කරයි.
# * **නීති ප්‍රකාශනය:** ජනාධිපතිවරයා විසින් අනු
# ====================================
#
# === Answers WITH RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# Retrieved Context: (2) පාර්ලිමේන්තුව විසින් ආණ්ඩුවේ ප්‍රතිපත්ති ප්‍රකාශය හෝ විසර්ජන පනත් කෙටුම්පත හෝ ප්‍රතික්ෂේප කළහොත් එවිට ද, ආණ්ඩුව කෙරෙහි විශ්වාසභංග යෝජනාවක් සම්මත කළහොත් එවිට ද, අමාත්‍ය මණ්ඩලය විසිරෙන්නේ ය. එසේ වූ විට 70 වන ව්‍යවස්ථාව යටතේ ස්වකීය බලතල ක්‍රියාත්මක කරමින් ජනාධිපතිවරයා විසින් පාර්ලිමේන්තුව විසුරුවා හරිනු ලැබුවහොත් මිස, ජනාධිපතිවරයා විසින් 43 වන, 44 වන, 45 වන සහ 46 වන ව්‍යවස්ථා අනුව අග්‍රාමාත්‍යවරය�
ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධාන වලට අනුකුලව යම් කාරණයක් සම්බන්ධයෙන් මුළු ශ්‍රී ලංකාව ම හෝ එහි යම් කොටසක් සඳහා නීති සැදීමට (මේ පරිච්ඡේදය ඇතුළුව) ආණ්ඩුක්‍රම ව්‍යවස්ථාවෙන් පාර්ලිමේන්තුවට පැවරී ඇති බලතල හීන කරන්නාක් සේ කියවා තේරුම් ගැනීම හෝ නොකළ යුත්තේ ය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 33(10) වගන්තියේ සඳහන් වන්නේ, ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධානවලට අනුකූලව යම් කාරණයක් සම්බන්ධයෙන් මුළු ශ්‍රී ලංකාව හෝ එහි යම් කොටසක් සඳහා නීති සැදීමට ආණ්ඩුක්‍රම ව්‍යවස්ථාවෙන් පාර්ලිමේන්තුවට පැවරී ඇති බලතල හීන කරන ලෙස කිසිවක් අර්ථකථනය නොකළ යුතු බවයි.  මෙම වගන්තියෙන් ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලයක් ලබාදී ඇති බව
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# Retrieved Context: මේ ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ (ඉ) ඡේදයේ සඳහන් තැනැත්තන් පස්දෙනා නම් කිරීමේ දී, අවස්ථාවෝචිත පරිදි, අග්‍රාමාත්‍යවරයා, කථානායකවරයා සහ විරුද්ධ පක්ෂයේ නායකවරයා හෝ පාර්ලිමේන්තු මන්ත්‍රීවරයන් විසින් වෘත්තීය සහ සමාජයීය . විවිධත්වය ඇතුළුව ශ්‍රී ලාංකීය සමාජයේ බහුත්ත්ව ලක්ෂණය සභාවෙන් පිළිබිඹු වන බව සහතික කරනු ලැබිය යුත්තේ ය. 84. (1) ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයක් සංශෝධනය කිරීම සඳහා හෝ ආණ්ඩුක්‍රම ව්‍යවස්ථාව පරිච්ඡින්න කොට ප්‍රතියෝජනය කිරීම සඳහා හෝ නොවන, එහෙත් ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයකට අනනුකූල වූ පනත් කෙටුම්පතක්, 82 වන ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ හෝ (2) වන අනුව්‍යවස්ථාවේ හෝ නියමයන්ට අනුකූලව ක්‍රියා නොකොට පාර්ලිමේන්තුවේ න්‍යාය පත්‍රයට ඇතුළත් කළ හැක්කේය. (3) පරිපාලන භාෂාව වශයෙන් දෙමළ භාෂාව භාවිත කරනු ලබන යම් ප්‍රදේශයක, ස්වකීය නිල තත්ත්වයෙන් ක්‍රියා කරන නිලධරයකු නොවන යම් තැනැත්තකු මේ ව්‍යවස්ථාවේ (2) වන අනුව්‍යවස්ථාවේ (අ), (ආ) සහ (ඇ) ඡේදවල සඳහන් අයිතිවාසිකම් සහ සේවාවන් සිංහල භාෂාවෙන් හෝ ඉංග්‍රීසි භාෂාවෙන් ක්‍රියාත්මක කරවා ගැනීමට සහ ලබා ගැනීමට හිමිකම් ලැබිය යුත්තේ ය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 18 වන වගන්තියට අනුව, ශ්‍රී ලංකාවේ ජාතික භාෂා දෙක සිංහල හා දෙමළ ය.  ලබාදී ඇති සන්දර්භය ජාතික භාෂා ගැන සඳහන් නොකරයි.
#
# ====================================
#
# Q: ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?
# Retrieved Context: ඕ) වන ව්‍යවස්ථාව  ලිපිකරුවො  185[නියෙජ්‍ය පිස්කල්‌ නිලධරයෙ:] භාෂා පරිවර්තකයෙං  ලඝු ලේඛකයෙං  යතුරු ලේඛකයෙං  පොත්‌ බඳින්නෙං  හභයවන උපලේඛනය  162 2) චන ව්‍යවස්ථාව  කොළඹ නගරය සහ දෙහිවල-ගල්කිස්ස 2) එසේ නියම කරන ලද දිනයේ දී පාර්ලිමේන්තුව රැස්විය යුන්නේ ය. පාර්ලිමේන්නුව එසේ රැස්විය යුත්තේ කවර වේලාවක දැයි ජනාධිපනිවරයා විසින්‌ එම ප්‍රකාශනයෙහි නිශ්චය කොට දැක්විය හැක්කේ ය.  දෙවො වසයතු කාලෙන 'සස්‍යස සමපතනි හොතු ව වීතො හවතු ලොකො ච රාජා හවතු ධමමිකො  විසිඑක්වන ආණ්ඩුක්‍රම ව්‍යවස්ථා සංශෝධනයේ
ආණ්ඩුක්‍රම ව්‍යවස්ථාව ක්‍රියාත්මක වීම ආරම්භ වන තෙක්‌ ශ්‍රී ලංකාණ්ඩුවට අයත්ව තිබුණා වූ යම්කිසි අයිතිවාසිකමක්‌, යුතුකමක්‌ හෙ බැඳීමක්‌ හෝ වේ ද ඒ සියලු අයිතිවාසිකම්‌, යුතුකම්‌ හා බැඳීම්‌ ආණ්ඩුක්‍රම වාවස්ථාව යටතේ ශ්‍රී ලංකා ජනරජයේ ආණ්ඩුවට පැවරෙන්නේ ය.   168.
# A: මෙම ප්‍රශ්නයට පිළිතුරු දීම සඳහා ලබාදී ඇති තොරතුරු ප්‍රමාණවත් නොවේ.  ලබාදී ඇති ඡේද ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ කොටස් වන අතර ඒවා රාජ්‍ය බලය, ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ ක්‍රියාත්මක වීම ආදිය ගැන සඳහන් කරයි. ශ්‍රී ලංකා ජාතික කොඩියේ බෝ කොළ හතරේ අර්ථය ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ සඳහන් නොවේ.  එබැවින්, මෙම ප්‍රශ්නයට පිළිතුරු දීමට මට ලබාදී ඇති තොරතුරු ප්‍රමාණවත් නොවේ.
#
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# Retrieved Context: (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික
# A: ඔව්, ටෝකියෝ ජපානයේ අගනුවරයි.  මෙම ප්‍රශ්නයට ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 154[XVIIIඅ] වන පරිච්ඡේදය හෝ එහි ඕනෑම කොටසක් සම්බන්ධයක් නැත.
#
# ====================================
#
# Q: What are the powers of the President of Sri Lanka?
# Retrieved Context: (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික
# A: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාට බලතල රාශියක් ඇති අතර ඒවා ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විවිධ වගන්තිවල දක්වා ඇත.  නමුත් ඔබ දී ඇති සන්දර්භය (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික) ප්‍රමාණවත් නොවේ ජනාධිපතිවරයාගේ සම්පූර්ණ බලතල ලැයිස්තුවක් ලබා දීමට.  XVIII වන පරිච්ඡේදය හා XVIIIඅ වන පරිච්ඡේදය යනු කුමක්ද යන්න පැහැදිලි නැත.  එබැවින්, ජනාධිපතිවරයාග
# ====================================
#
# Q: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?
# Retrieved Context: (ආ) එවැනි කිසිම යෝජනා සම්මතයක් පිළිබඳ දැන්වීමක්, එය (අ) ඡේදයේ විධිවිධානවලට අනුකූල වේ නම් මිස සහ- (3) ශ්‍රී ලංකාවේ ස්වාධීනත්වය, ස්වෛරීභාවය, එක්සත් බව හා දේශ පූර්ණත්වය ද රජය විසින් ආරක්ෂා කළ යුත්තේ ය. ( 2 ) ශ්‍රී ලංකාවේ පුරවැසියකුට, පුරවැසිභාවය හිමි වූයේ පරම්පරාවෙන් වුව ද, පුරවැසිභාවය පිළිබඳ නීතියට අනුකූලව ලියාපදිංචි වීමෙන් වුව ද, ඒ තැනැත්තා සියලු කාර්ය සඳහා '' ශ්‍රී ලංකාවේ පුරවැසියෙක්" යනුවෙන් පමණක් විස්තර කරනු ලබන්නේය.
# A: මෙම ලබාදුන් සන්දර්භය ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල පිළිබඳව කිසිදු තොරතුරක් ලබා නොදේ.  එබැවින්, ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 4 වන පරිච්ඡේදය (ජනාධිපති) යොමු කරමින් ජනාධිපතිවරයාගේ බලතල පිළිබඳව සාමාන්‍ය දැනුම මත පදනම්ව පිළිතුරු ලබා දිය හැකිය.
#
# ශ්‍රී ලංකාවේ ජනාධිපතිවරයා රාජ්‍ය නායකයා සහ රාජ්‍ය හිමිකම්කරුවා වේ. ඔහුට පහත සඳහන් බලතල ඇත:
#
# * **කැ
# ====================================

# %% [markdown]
# Performance Comparison: With vs. Without RAG
#
# **Responses Without RAG**
#
# Gemini generates factually correct answers most of the time without referring to the actual constitution.
# Answers are concise, well-structured, and fluent in Sinhala.
#
# Potential Issues:
#
# Some answers lack legal references or specific constitutional articles.
# Answers may be based on general knowledge rather than the actual Sri Lankan Constitution.
# Partial answers (e.g., the pardon question was incomplete).
#
# Example:
# Question: "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?"
#
# Answer Without RAG:
# "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව රටේ ජාතික භාෂා දෙකක් තිබේ: සිංහල සහ தமிழ் (தமிழ்)."
#
# Correct but lacks a specific legal reference to a constitutional article.
#
# **Responses With RAG (Retrieval-Augmented Generation)**
#
# The chatbot retrieves relevant context from the constitution before answering.
# Legal references (constitutional clauses) are included in responses.
# More trustworthy and verifiable answers.
#
# Potential Issues:
#
# Sometimes irrelevant or too much text is retrieved.
# Some answers still cut off or remain incomplete (possible Gemini truncation issue).
#
# Example:
# Question: "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?"
# Retrieved Context: Mentions governance, official languages, and legislative authority.
#
# Answer With RAG:
#
# "ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ ඒ ගැන සෘජුවම සඳහන් වන්නේ නැත. කෙසේ වුවද, ලබාදී ඇති උපුටා ගැනීම්වලින් හෝ ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ වෙනත් වගන්තිවලින් හෝ ජාතික භාෂා ලෙස සිංහල හා දෙමළ භාෂා දෙකම හඳුනාගත හැකිය."
#
# More accurate than the non-RAG answer, but vague about the exact constitutional article.
#
# Strengths of the Chatbot
#
# Fluent Sinhala Generation: Gemini provides highly fluent and natural Sinhala responses.
#
# Handles Constitutional Queries Well: Even without RAG, Gemini understands legal concepts and provides correct responses.
#
# RAG Improves Credibility: The retrieved context from the constitution improves factual accuracy.
#
# FastText Enhances Query Understanding: The FastText embeddings with BPE tokenization help handle morphologically complex Sinhala words, improving query retrieval accuracy.

# %%
# Retrieve and configure the Gemini API key from Colab secrets
GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("GOOGLE_API_KEY not found. Please set it in Colab secrets.")
genai.configure(api_key=GOOGLE_API_KEY)

# Loading FastText and SentencePiece models
FASTTEXT_MODEL_PATH = "fasttext_sinhala_bpe.model"
BPE_MODEL_PATH = "sinhala_spm_bpe.model"
CONSTITUTION_PATH = "/content/drive/MyDrive/Sri Lanka Constitution-Sinhala.txt"

ft_model = FastText.load(FASTTEXT_MODEL_PATH)
sp = spm.SentencePieceProcessor(model_file=BPE_MODEL_PATH)

# Loading Constitution passages
with open(CONSTITUTION_PATH, "r", encoding="utf-8") as f:
    passages = [line.strip() for line in f if line.strip()]

# Computing averaged FastText embedding using BPE tokens
def get_embedding(text):
    tokens = sp.encode(text, out_type=str)
    valid_vectors = [ft_model.wv[t] for t in tokens if t in ft_model.wv.key_to_index]
    return np.mean(valid_vectors, axis=0) if valid_vectors else np.zeros(ft_model.vector_size)

# Precomputing passage embeddings and build a nearest neighbor index (cosine similarity)
passage_embeddings = np.array([get_embedding(p) for p in passages])
nn = NearestNeighbors(n_neighbors=3, metric="cosine")  # Retrieving top 3 passages
nn.fit(passage_embeddings)

# Retrieving context from the Constitution based on the question
def retrieve_context(question):
    query_emb = get_embedding(question).reshape(1, -1)
    distances, indices = nn.kneighbors(query_emb)
    return " ".join([passages[i] for i in indices[0]])

# Initializing the Gemini model
model = genai.GenerativeModel("gemini-1.5-flash")

# Generate an answer using the Gemini API
def generate_answer(prompt, max_tokens=300):
    response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            max_output_tokens=max_tokens,
            temperature=0.1
        )
    )
    return response.text

# Answer without RAG: Direct generation without context
def answer_without_rag(question):
    prompt = f"Q: {question}\nA:"
    return generate_answer(prompt)

# Answer with RAG: Combine retrieved context with the question
def answer_with_rag(question):
    context = retrieve_context(question)
    print("Retrieved Context:", context)
    prompt = (
        f"Instructions: Use the provided context to answer the question accurately and completely in Sinhala. "
        f"Include specific references to articles or sections of the Sri Lankan Constitution when relevant. "
        f"If the context is insufficient or irrelevant, use your general knowledge to provide a correct answer.\n"
        f"Context: {context}\n"
        f"Q: {question}\n"
        f"A:"
    )
    return generate_answer(prompt)

# Sample questions for testing
sample_questions = [
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?",
    "ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?",
    "ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?",
    "Is Tokyo the capital city of Japan ?",
    "What are the powers of the President of Sri Lanka?",
    "ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?"
]

# Test both approaches
print("=== Answers WITHOUT RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_without_rag(q))
    print("====================================\n")

print("=== Answers WITH RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_with_rag(q))
    print("====================================\n")
# Out:
# === Answers WITHOUT RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# A: ඔව්, ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අග්‍රාමාත්‍යවරයාය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලය ඇත, නමුත් එම බලය සීමා සහිතය.  ව්‍යවස්ථාවේ 34(1) වගන්තියට අනුව, ජනාධිපතිවරයාට ඕනෑම චෝදනාවකට හෝ වරදකට සමාව ලබා දිය හැකිය.  කෙසේ වුවද, මෙම බලය සම්පූර්ණයෙන්ම අසීමිත නොවේ.
#
# විශේෂයෙන්ම, ජනාධිපතිවරයාට පාර්ලිමේන්තුව විසින් චෝදනා ගොනු කරන ලද වරදකට සමාව ලබා දිය නොහැක.  එසේම, යම් වරදක් ස
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව රටේ ජාතික භාෂා දෙකක් තිබේ: **සිංහල** සහ **தமிழ் (தமிழ்)**.
#
# ====================================
#
# Q: ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?
# A: ඕස්ට්‍රේලියාවේ අගනුවර **කැන්බරා** ය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?
# A: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ හතර ශ්‍රී ලංකාවේ ඓතිහාසික රාජධානි හතර නියෝජනය කරයි. ඒවා නම්:
#
# * **අනුරාධපුර**
# * **පොළොන්නරුව**
# * **කුරුණෑගල**
# * **කොට්ටේ**
#
# මෙම රාජධානි හතර ශ්‍රී ලංකාවේ ඓතිහාසික හා සංස්කෘතික උරුමයේ වැදගත් අංග වේ.
#
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# A: Yes, Tokyo is the capital city of Japan.
#
# ====================================
#
# Q: What are the powers of the President of Sri Lanka?
# A: The President of Sri Lanka holds significant power, functioning as both head of state and head of government.  Their powers are extensive and encompass various aspects of governance, though they are subject to checks and balances (though these have been weakened in recent years).  Key powers include:
#
# **Executive Powers:**
#
# * **Appointing Power:**  The President appoints the Prime Minister (usually the leader of the majority party in Parliament), other ministers, judges of the Supreme Court and other superior courts, and high-ranking officials in the civil service and armed forces.
# * **Legislative Powers:**  While Parliament makes laws, the President has significant influence. They can:
#     * Summon, prorogue, and dissolve Parliament.
#     * Introduce legislation (though most bills originate in Parliament).
#     * Assent to or withhold assent from bills passed by Parliament.  A bill can become law even without Presidential assent after a certain period.
#     * Issue ordinances (emergency laws) with the force of law, subject to parliamentary approval later.
# * **Executive Orders:** The President can issue executive orders that have the force of law within the limits of their constitutional authority.
# * **Commander-in-Chief:** The President is the supreme commander of the armed forces.
# * **Pardon and Reprieve:** The President has the power to grant pardons, reprieves, and commutations of sentences.
# * **Emergency Powers:**  The President can declare a state of emergency under specific circumstances,
# ====================================
#
# Q: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?
# A: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාට බහුල බලතල ඇති අතර ඒවා ප්‍රධාන වශයෙන් කාණ්ඩ තුනකට බෙදිය හැකිය:
#
# **1. විධායක බලතල:**
#
# * **රජයේ ප්‍රධානියා:** ජනාධිපතිවරයා රජයේ ප්‍රධානියා වන අතර, රටේ පරිපාලනය හා ආණ්ඩුවේ කටයුතු භාරව සිටී.
# * **ඇමති මණ්ඩලය පත් කිරීම:** ජනාධිපතිවරයා ඇමති මණ්ඩලය පත් කරන අතර, ඔවුන්ගේ කටයුතු හා ක්‍රියාකාරකම් පිළිබඳව අධීක්ෂණය කරයි.
# * **නීති ප්‍රකාශනය:** ජනාධිපත
# ====================================
#
# === Answers WITH RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# Retrieved Context: (2) පාර්ලිමේන්තුව විසින් ආණ්ඩුවේ ප්‍රතිපත්ති ප්‍රකාශය හෝ විසර්ජන පනත් කෙටුම්පත හෝ ප්‍රතික්ෂේප කළහොත් එවිට ද, ආණ්ඩුව කෙරෙහි විශ්වාසභංග යෝජනාවක් සම්මත කළහොත් එවිට ද, අමාත්‍ය මණ්ඩලය විසිරෙන්නේ ය. එසේ වූ විට 70 වන ව්‍යවස්ථාව යටතේ ස්වකීය බලතල ක්‍රියාත්මක කරමින් ජනාධිපතිවරයා විසින් පාර්ලිමේන්තුව විසුරුවා හරිනු ලැබුවහොත් මිස, ජනාධිපතිවරයා විසින් 43 වන, 44 වන, 45 වන සහ 46 වන ව්‍යවස්ථා අනුව අග්‍රාමාත්‍යවරයෙක් ද, අමාත්‍ය මණ්ඩලයේ අමාත්‍යවරයන් ද, අමාත්‍ය මණ්ඩලයේ සාමාජිකයන් නොවන අමාත්‍යවරයන් ද, නියෝජ්‍ය අමාත්‍යවරයන් ද පත් කළ යුත්තේ ය. (4) ප්‍රඥප්තියක් (2) වන අනුව්‍යවස්ථාව යටතේ ආණ්ඩුකාරවරයා වෙත ඉදිරිපත් කරනු ලැබූ විට, ආණ්ඩුකාරවරයා විසින් එයට අනුමතය දීම හෝ එම ප්‍රඥප්තිය ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධානවලට අනුක
ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ කොටස් වන අතර ඒවා ශ්‍රී ලංකා ජාතික කොඩියේ බෝ කොළ හතරේ අර්ථය පැහැදිලි කරන්නේ නැත.  ශ්‍රී ලංකා ජාතික කොඩියේ බෝ කොළ හතර බුදු දහමේ ශාඛා හතර නියෝජනය කරන බව සාමාන්‍ය දැනුමෙන් දන්නා කරුණකි.
#
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# Retrieved Context: (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික
# A: ඔව්, ටෝකියෝ ජපානයේ අගනුවරයි.  මෙම ප්‍රශ්නයට ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 154[XVIIIඅ] වන පරිච්ඡේදය හෝ එහි යම් කොටසක් සම්බන්ධ නොවේ.
#
# ====================================
#
# Q: What are the powers of the President of Sri Lanka?
# Retrieved Context: (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික
# A: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාට බලතල රාශියක් ඇති අතර ඒවා ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විවිධ වගන්තිවල දක්වා ඇත.  නිශ්චිතවම 18 වන පරිච්ඡේදය (හෝ XVIII අ පරිච්ඡේදය යනුවෙන් ඔබ සඳහන් කර ඇති ආකාරයට) ජාතික රජය සම්බන්ධයෙන් විස්තර කරන බව ඔබේ ප්‍රශ්නයේ ඇති තොරතුරුවලින් පැහැදිලි නොවේ.  කෙසේ වෙතත්, ජනාධිපතිවරයාගේ ප්‍රධාන බලතල කිහිපයක් මෙසේය:
#
# * **කාර්යාංශික බලතල:** ජ
# ====================================
#
# Q: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?
# Retrieved Context: (ආ) එවැනි කිසිම යෝජනා සම්මතයක් පිළිබඳ දැන්වීමක්, එය (අ) ඡේදයේ විධිවිධානවලට අනුකූල වේ නම් මිස සහ- (3) ශ්‍රී ලංකාවේ ස්වාධීනත්වය, ස්වෛරීභාවය, එක්සත් බව හා දේශ පූර්ණත්වය ද රජය විසින් ආරක්ෂා කළ යුත්තේ ය. ( 2 ) ශ්‍රී ලංකාවේ පුරවැසියකුට, පුරවැසිභාවය හිමි වූයේ පරම්පරාවෙන් වුව ද, පුරවැසිභාවය පිළිබඳ නීතියට අනුකූලව ලියාපදිංචි වීමෙන් වුව ද, ඒ තැනැත්තා සියලු කාර්ය සඳහා '' ශ්‍රී ලංකාවේ පුරවැසියෙක්" යනුවෙන් පමණක් විස්තර කරනු ලබන්නේය.
# A: මෙම ලබාදුන් සන්දර්භය ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල පිළිබඳව කිසිදු තොරතුරක් ලබා නොදේ.  එබැවින්, ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 4 වන පරිච්ඡේදය (ජනාධිපති) යොමු කරමින් ජනාධිපතිවරයාගේ බලතල පිළිබඳව සාමාන්‍ය දැනුම මත පදනම්ව පිළිතුරු ලබා දිය හැකිය.
#
# ශ්‍රී ලංකාවේ ජනාධිපතිවරයා රාජ්‍ය නායකයා සහ රාජ්‍ය හිමිකරු වේ. ඔහුට ප්‍රධාන වශයෙන් පහත බලතල ඇත:
#
# * **ක
# ====================================

# %%
# Retrieve and configure the Gemini API key from Colab secrets
GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("GOOGLE_API_KEY not found. Please set it in Colab secrets.")
genai.configure(api_key=GOOGLE_API_KEY)

# Loading FastText and SentencePiece models
FASTTEXT_MODEL_PATH = "fasttext_sinhala_bpe.model"
BPE_MODEL_PATH = "sinhala_spm_bpe.model"
CONSTITUTION_PATH = "/content/drive/MyDrive/Sri Lanka Constitution-Sinhala.txt"

ft_model = FastText.load(FASTTEXT_MODEL_PATH)
sp = spm.SentencePieceProcessor(model_file=BPE_MODEL_PATH)

# Loading Constitution passages
with open(CONSTITUTION_PATH, "r", encoding="utf-8") as f:
    passages = [line.strip() for line in f if line.strip()]

# Computing averaged FastText embedding using BPE tokens
def get_embedding(text):
    tokens = sp.encode(text, out_type=str)
    valid_vectors = [ft_model.wv[t] for t in tokens if t in ft_model.wv.key_to_index]
    return np.mean(valid_vectors, axis=0) if valid_vectors else np.zeros(ft_model.vector_size)

# Precomputing passage embeddings and build a nearest neighbor index (cosine similarity)
passage_embeddings = np.array([get_embedding(p) for p in passages])
nn = NearestNeighbors(n_neighbors=3, metric="cosine")  # Retrieving top 3 passages
nn.fit(passage_embeddings)

# Retrieving context from the Constitution based on the question
def retrieve_context(question):
    query_emb = get_embedding(question).reshape(1, -1)
    distances, indices = nn.kneighbors(query_emb)
    return " ".join([passages[i] for i in indices[0]])

# Initializing the Gemini model
model = genai.GenerativeModel("gemini-1.5-flash")

# Generate an answer using the Gemini API
def generate_answer(prompt, max_tokens=500):
    response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            max_output_tokens=max_tokens,
            temperature=0.2
        )
    )
    return response.text

# Answer without RAG: Direct generation without context
def answer_without_rag(question):
    prompt = f"Q: {question}\nA:"
    return generate_answer(prompt)

# Answer with RAG: Combine retrieved context with the question
def answer_with_rag(question):
    context = retrieve_context(question)
    print("Retrieved Context:", context)
    prompt = (
        f"Instructions: Use the provided context to answer the question accurately and completely in Sinhala. "
        f"Include specific references to articles or sections of the Sri Lankan Constitution when relevant. "
        f"If the context is insufficient or irrelevant, use your general knowledge to provide a correct answer.\n"
        f"Context: {context}\n"
        f"Q: {question}\n"
        f"A:"
    )
    return generate_answer(prompt)

# Sample questions for testing
sample_questions = [
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?",
    "ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?",
    "ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?",
    "Is Tokyo the capital city of Japan ?",
    "What are the powers of the President of Sri Lanka?",
    "ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?"
]

# Test both approaches
print("=== Answers WITHOUT RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_without_rag(q))
    print("====================================\n")

print("=== Answers WITH RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_with_rag(q))
    print("====================================\n")
# Out:
# === Answers WITHOUT RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# A: ඔව්, ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අග්‍රාමාත්‍යවරයාය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලය ඇත, නමුත් එම බලය සීමා සහිතය.  ව්‍යවස්ථාවේ 34(1) වගන්තියට අනුව, ජනාධිපතිවරයාට ඕනෑම චෝදනාවකට හෝ වරදකට සමාව ලබාදිය හැකිය.  කෙසේ වුවද, මෙම බලය සම්පූර්ණයෙන්ම නිරපේක්ෂ නොවේ.
#
# විශේෂයෙන්ම, ජනාධිපතිවරයාට පහත සඳහන් අවස්ථාවලදී සමාව ලබාදිය නොහැක:
#
ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ (ඉ) ඡේදයේ සඳහන් තැනැත්තන් පස්දෙනා නම් කිරීමේ දී, අවස්ථාවෝචිත පරිදි, අග්‍රාමාත්‍යවරයා, කථානායකවරයා සහ විරුද්ධ පක්ෂයේ නායකවරයා හෝ පාර්ලිමේන්තු මන්ත්‍රීවරයන් විසින් වෘත්තීය සහ සමාජයීය . විවිධත්වය ඇතුළුව ශ්‍රී ලාංකීය සමාජයේ බහුත්ත්ව ලක්ෂණය සභාවෙන් පිළිබිඹු වන බව සහතික කරනු ලැබිය යුත්තේ ය. 84. (1) ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයක් සංශෝධනය කිරීම සඳහා හෝ ආණ්ඩුක්‍රම ව්‍යවස්ථාව පරිච්ඡින්න කොට ප්‍රතියෝජනය කිරීම සඳහා හෝ නොවන, එහෙත් ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයකට අනනුකූල වූ පනත් කෙටුම්පතක්, 82 වන ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ හෝ (2) වන අනුව්‍යවස්ථාවේ හෝ නියමයන්ට අනුකූලව ක්‍රියා නොකොට පාර්ලිමේන්තුවේ න්‍යාය පත්‍රයට ඇතුළත් කළ හැක්කේය. (3) පරිපාලන භාෂාව වශයෙන් දෙමළ භාෂාව භාවිත කරනු ලබන යම් ප්‍රදේශයක, ස්වකීය නිල තත්ත්වයෙන් ක්‍රියා කරන නිලධරයකු නොවන යම් තැනැත්තකු මේ ව්‍යවස්ථාවේ (2) වන අනුව්‍යවස්ථාවේ (අ), (ආ) සහ (ඇ) ඡේදවල සඳහන් අයිතිවාසිකම් සහ සේවාවන් සිංහල භාෂාවෙන් හෝ ඉංග්‍රීසි භාෂාවෙන් ක්‍රියාත්මක කරවා ගැනීමට සහ ලබා ගැනීමට හිමිකම් ලැබිය යුත්තේ ය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 18 වන වගන්තියට අනුව, ශ්‍රී ලංකාවේ ජාතික භාෂා දෙක සිංහල හා දෙමළ ය.  ලබාදී ඇති පාඨයේ මෙම තොරතුරු නොමැති බැවින්, මෙම පිළිතුර මගේ සාමාන්‍ය දැනුම මත පදනම් වේ.
#
# ====================================
#
# Q: ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?
# Retrieved Context: ඕ) වන ව්‍යවස්ථාව  ලිපිකරුවො  185[නියෙජ්‍ය පිස්කල්‌ නිලධරයෙ:] භාෂා පරිවර්තකයෙං  ලඝු ලේඛකයෙං  යතුරු ලේඛකයෙං  පොත්‌ බඳින්නෙං  හභයවන උපලේඛනය  162 2) චන ව්‍යවස්ථාව  කොළඹ නගරය සහ දෙහිවල-ගල්කිස්ස 2) එසේ නියම කරන ලද දිනයේ දී පාර්ලිමේන්තුව රැස්විය යුන්නේ ය. පාර්ලිමේන්නුව එසේ රැස්විය යුත්තේ කවර වේලාවක දැයි ජනාධිපනිවරයා විසින්‌ එම ප්‍රකාශනයෙහි නිශ්චය කොට දැක්විය හැක්කේ ය.  දෙවො වසයතු කාලෙන 'සස්‍යස සමපතනි හොතු ව වීතො හවතු ලොකො ච රාජා හවතු ධමමිකො  විසිඑක්වන ආණ්ඩුක්‍රම ව්‍යවස්ථා සංශෝධනයේ අනෙකුත්‌ ආනුෂංගික සංශෝධන  30.
# A: මෙම ප්‍රශ්නයට පිළිතුරු දීමට ලබාදී ඇති සන්දර්භය ප්‍රමාණවත් නොවේ.  ලබාදී ඇති සන්දර්භය ශ්‍රී ලංකාවේ ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ කොටස් සහ ඒ ආශ්‍රිත තොරතුරු පමණක් අඩංගු වේ. ඕස්ට්‍රේලියාවේ අගනුවර කුමක්
ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ හතරේ අර්ථය පැහැදිලි කරන්නේ නැත.  ශ්‍රී ලංකා ජාතික කොඩියේ බෝ කොළ හතර ශ්‍රී ලංකාවේ බුද්ධාගමේ වැදගත්කම නිරූපණය කරන බව මගේ දැනුම අනුව මම දනිමි.
#
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# Retrieved Context: (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික
# A: ඔව්, ටෝකියෝ ජපානයේ අගනුවරයි.  මෙම ප්‍රශ්නයට ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 154[XVIIIඅ] වන පරිච්ඡේදය හෝ එහි වෙනත් කොටස් සම්බන්ධයක් නැත.
#
# ====================================

# %%
# Retrieve and configure the Gemini API key from Colab secrets
GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("GOOGLE_API_KEY not found. Please set it in Colab secrets.")
genai.configure(api_key=GOOGLE_API_KEY)

# Loading FastText and SentencePiece models
FASTTEXT_MODEL_PATH = "fasttext_sinhala_bpe.model"
BPE_MODEL_PATH = "sinhala_spm_bpe.model"
CONSTITUTION_PATH = "/content/drive/MyDrive/Sri Lanka Constitution-Sinhala.txt"

ft_model = FastText.load(FASTTEXT_MODEL_PATH)
sp = spm.SentencePieceProcessor(model_file=BPE_MODEL_PATH)

# Loading Constitution passages
with open(CONSTITUTION_PATH, "r", encoding="utf-8") as f:
    passages = [line.strip() for line in f if line.strip()]

# Computing averaged FastText embedding using BPE tokens
def get_embedding(text):
    tokens = sp.encode(text, out_type=str)
    valid_vectors = [ft_model.wv[t] for t in tokens if t in ft_model.wv.key_to_index]
    return np.mean(valid_vectors, axis=0) if valid_vectors else np.zeros(ft_model.vector_size)

# Precomputing passage embeddings and build a nearest neighbor index (cosine similarity)
passage_embeddings = np.array([get_embedding(p) for p in passages])
nn = NearestNeighbors(n_neighbors=3, metric="cosine")  # Retrieving top 3 passages
nn.fit(passage_embeddings)

# Retrieving context from the Constitution based on the question
def retrieve_context(question):
    query_emb = get_embedding(question).reshape(1, -1)
    distances, indices = nn.kneighbors(query_emb)
    return " ".join([passages[i] for i in indices[0]])

# Initializing the Gemini model
model = genai.GenerativeModel("gemini-1.5-flash")

# Generate an answer using the Gemini API
def generate_answer(prompt, max_tokens=700):
    response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            max_output_tokens=max_tokens,
            temperature=0.2
        )
    )
    return response.text

# Answer without RAG: Direct generation without context
def answer_without_rag(question):
    prompt = f"Q: {question}\nA:"
    return generate_answer(prompt)

# Answer with RAG: Combine retrieved context with the question
def answer_with_rag(question):
    context = retrieve_context(question)
    print("Retrieved Context:", context)
    prompt = (
        f"Instructions: Use the provided context to answer the question accurately and completely in Sinhala. "
        f"Include specific references to articles or sections of the Sri Lankan Constitution when relevant. "
        f"If the context is insufficient or irrelevant, use your general knowledge to provide a correct answer.\n"
        f"Context: {context}\n"
        f"Q: {question}\n"
        f"A:"
    )
    return generate_answer(prompt)

# Sample questions for testing
sample_questions = [
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?",
    "ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?",
    "ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?",
    "Is Tokyo the capital city of Japan ?",
    "What are the powers of the President of Sri Lanka?",
    "ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?"
]

# Test both approaches
print("=== Answers WITHOUT RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_without_rag(q))
    print("====================================\n")

print("=== Answers WITH RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_with_rag(q))
    print("====================================\n")
# Out:
# === Answers WITHOUT RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# A: ඔව්, ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අග්‍රාමාත්‍යවරයාය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව, ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලය ඇත, නමුත් එම බලය සීමා සහිතය.  ව්‍යවස්ථාවේ 34(1) වගන්තියට අනුව, ජනාධිපතිවරයාට ඕනෑම චෝදනාවකට හෝ වරදකට සමාව ලබාදිය හැකිය.  කෙසේ වුවද, මෙම බලය සම්පූර්ණයෙන්ම අසීමිත නොවේ.
#
# විශේෂයෙන්ම, ජනාධිපතිවරයාට පහත සඳහන් අවස්ථාවලදී සමාව ලබාදිය නොහැක:
#
# * **මහජන නියෝජිතයින්ගේ හෝ රාජ්‍ය නිලධාරීන්ගේ වංචා චෝදනා:**  මෙම චෝදනා සම්බන්ධයෙන් ජනාධිපතිවරයාට සමාව ලබාදිය හැක්කේ පාර්ලිමේන්තුවේ තුනෙන් දෙකක බහුතර ඡන්දයකින් පසුව පමණි.
# * **ව්‍යවස්ථාව උල්ලංඝනය කිරීම:** ව්‍යවස්ථාවේ පැහැදිලිව සඳහන් කර ඇති උල්ලංඝනයන් සඳහා ජනාධිපතිවරයාට සමාව ලබාදිය නොහැක.
#
# එබැවින්, ජනාධිපතිවරයාට සමාව ලබාදීමේ බලය තිබුණද, එම බලය අසීමිත නොවන අතර, ව්‍යවස්ථාවේ සීමාවන්ට යටත් වේ.  විශේෂිත චෝදනාවක් සම්බන්ධයෙන් ජනාධිපතිවරයාට සමාව ලබාදිය හැකිද යන්න තීරණය කිරීම සඳහා, එම චෝදනාවේ ස්වභාවය සහ ව්‍යවස්ථ
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව රටේ ජාතික භාෂා දෙකක් තිබේ: **සිංහල** සහ **தமிழ் (தமிழ்)**.
#
# ====================================
#
# Q: ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?
# A: ඕස්ට්‍රේලියාවේ අගනුවර **කැන්බරා** ය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?
# A: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ හතර ශ්‍රී ලංකාවේ ඓතිහාසික බුද්ධිමත් ජනතාවගේ ධර්මය, ශිෂ්ටාචාරය, සමෘද්ධිය සහ සාමය යන සංකේත වේ.  ඒවා බුදුදහමේ ශාඛා හතරක් හෝ බුදුදහමේ ප්‍රධාන මූලධර්ම හතරක් නියෝජනය කරන බවටත් මතයක් තිබේ.  කෙසේ වෙතත්,  මෙය නිල වශයෙන් තහවුරු කරන ලද අර්ථකථනයක් නොවේ.
#
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# A: Yes, Tokyo is the capital city of Japan.
#
# ====================================
#
# Q: What are the powers of the President of Sri Lanka?
# A: The President of Sri Lanka holds significant executive power, though the extent of these powers has fluctuated throughout the country's history due to constitutional amendments.  Here's a summary of their key powers:
#
# **Executive Powers:**
#
# * **Head of State and Government:** The President is both the Head of State, representing Sri Lanka internationally, and the Head of Government, leading the executive branch.
# * **Commander-in-Chief:**  The President is the Supreme Commander of the armed forces.
# * **Appointment Powers:**  The President appoints the Prime Minister (usually the leader of the majority party in Parliament), other ministers, judges, and high-ranking officials.  The extent of this power is subject to parliamentary approval in some cases.
# * **Legislative Powers:** While Parliament holds primary legislative power, the President can:
#     * **Summon, prorogue, and dissolve Parliament:** This gives the President considerable influence over the legislative process.
#     * **Veto legislation:** The President can veto bills passed by Parliament, though Parliament can override a veto with a two-thirds majority.
#     * **Issue ordinances:**  In certain circumstances, the President can issue ordinances with the force of law, subject to parliamentary approval later.
# * **Executive Orders:** The President can issue executive orders to implement laws and policies.
# * **Pardon and Reprieve:** The President has the power to grant pardons and reprieves.
# * **Emergency Powers:**  The President can declare a state of emergency, granting broad powers to the executive branch to maintain order and security.  These powers are subject to parliamentary oversight, but the President has considerable discretion in their use.
#
# **Other Powers:**
#
# * **Foreign Policy:** The President plays a significant role in shaping Sri Lanka's foreign policy.
# * **International Treaties:** The President negotiates and ratifies international treaties.
#
#
# **Important Considerations:**
#
# * **Constitutional Amendments:** The powers of the President have been significantly altered by various constitutional amendments throughout Sri Lanka's history, shifting the balance of power between the executive and legislature.
# * **Parliamentary System:** While the President holds considerable power, Sri Lanka operates under a hybrid system with a strong parliamentary component.  The President's actions are often subject to parliamentary scrutiny and approval.
# * **Judicial Review:** The Supreme Court can review the constitutionality of the President's actions.
#
#
# In short, the President of Sri Lanka possesses extensive executive powers, including the ability to influence the legislative process, control the military, and shape foreign policy. However, these powers are not absolute and are subject to checks and balances within the constitutional framework.  The actual extent of the President's power depends on the political context and the specific constitutional provisions in effect at any given time.
#
# ====================================
#
# Q: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?
# A: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාට බලතල රාශියක් ඇති අතර ඒවා ප්‍රධාන වශයෙන් කාණ්ඩ තුනකට බෙදිය හැකිය:
#
# **1. විධායක බලතල:**
#
# * **රජයේ ප්‍රධානියා ලෙස:** රටේ ප්‍රධාන විධායකයා ලෙස, ජනාධිපතිවරයා රජයේ සියලුම අංශ පාලනය කරයි.  මැති ඇමතිවරුන් පත් කිරීම, ඉවත් කිරීම සහ ඔවුන්ගේ කටයුතු අධීක්ෂණය කිරීම ඔහුගේ යුතුකමයි.
# * **නීති රචනය:** ජනාධිපතිවරයාට පාර්ලිමේන්තුවට නීති යෝජනා ඉදිරිපත් කළ හැකිය.  එමෙන්ම, පාර්ලිමේන්තුවේ අනුමැතිය ලැබුණු නීති ඔහු විසින් අත්සන් කරනු ලැබේ.
# * **ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ බලතල:** ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධාන අනුව ජනාධිපතිවරයාට ඇතැම් විශේෂ බලතල හිමිවේ.  උදාහරණයක් ලෙස, හදිසි තත්ත්වයක් ප්‍රකාශ කිරීම, පාර්ලිමේන්තුව විසුරුවා හැරීම ආදිය.
# * **රාජ්‍ය සේවය:** රාජ්‍ය සේවයේ පත්කිරීම් සහ උසස්වීම් සම්බන්ධයෙන් ජනාධිපතිවරයාට බලපෑම් කළ හැකිය.
#
# **2. නිතිමය බලතල:**
#
# * **ප්‍රතිශෝධන බලය:** ජනාධිපතිවරයාට පාර්ලිමේන්තුව විසින් සම්මත කරන ලද නීති ප්‍රත
# ====================================
#
# === Answers WITH RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
ිෂන් සභාව වෙත පවරා දී ඇති යම් කර්තව්‍යයක් ඉටුකිරීමේ දී එකී සභාව විසින් කරන ලද යම් නියමයක් හෝ දෙන ලද යම් තීරණයක් පිළිබඳව විභාග කිරීමට, මතයක් ප්‍රකාශ කිරීමට හෝ කවර වූ හෝ ආකාරයකින් ප්‍රශ්න කිරීමට කිසිදු අධිකරණයකට හෝ විනිශ්චය අධිකාරයකට බලය හෝ අධිකරණ බලය නොතිබිය යුත්තේය. 33. ආණ්ඩුක්‍රම ව්‍යවස්ථාවෙන් හෝ යම් ලිඛිත නීතියකින් හෝ ප්‍රකාශිතව ම තමා වෙත පවරා හෝ නියම කර ඇත්තා වූ බලතලවලට සහ කාර්යයන්ට අමතරව, ජනාධිපතිවරයාට — (10) මේ ව්‍යවස්ථාවේ ඇතුළත් කිසිවක් ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධාන වලට අනුකුලව යම් කාරණයක් සම්බන්ධයෙන් මුළු ශ්‍රී ලංකාව ම හෝ එහි යම් කොටසක් සඳහා නීති සැදීමට (මේ පරිච්ඡේදය ඇතුළුව) ආණ්ඩුක්‍රම ව්‍යවස්ථාවෙන් පාර්ලිමේන්තුවට පැවරී ඇති බලතල හීන කරන්නාක් සේ කියවා තේරුම් ගැනීම හෝ නොකළ යුත්තේ ය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 33(10) වගන්තියේ සඳහන් වන්නේ, ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධානවලට අනුකූලව යම් කාරණයක් සම්බන්ධයෙන් මුළු ශ්‍රී ලංකාව හෝ එහි යම් කොටසක් සඳහා නීති සැදීමට ආණ්ඩුක්‍රම ව්‍යවස්ථාවෙන් පාර්ලිමේන්තුවට පැවරී ඇති බලතල හීන කරන ලෙස කිසිවක් අර්ථකථනය නොකළ යුතු බවයි.  මෙම වගන්තියෙන් ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලයක් ලබාදී ඇති බවක් පැහැදිලිව සඳහන් නොවේ.  එබැවින්, ලබාදී ඇති තොරතුරු පමණක් භාවිතා කරමින්, ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පූර්ණ සමාව ලබාදීමේ බලයක් තිබේද යන්න පිළිබඳව නිශ්චිතව ප්‍රකාශ කිරීමට නොහැකිය.  මෙම කාරණය පිළිබඳව වැඩිදුර විමර්ශනයක් අවශ්‍ය වේ.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# Retrieved Context: මේ ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ (ඉ) ඡේදයේ සඳහන් තැනැත්තන් පස්දෙනා නම් කිරීමේ දී, අවස්ථාවෝචිත පරිදි, අග්‍රාමාත්‍යවරයා, කථානායකවරයා සහ විරුද්ධ පක්ෂයේ නායකවරයා හෝ පාර්ලිමේන්තු මන්ත්‍රීවරයන් විසින් වෘත්තීය සහ සමාජයීය . විවිධත්වය ඇතුළුව ශ්‍රී ලාංකීය සමාජයේ බහුත්ත්ව ලක්ෂණය සභාවෙන් පිළිබිඹු වන බව සහතික කරනු ලැබිය යුත්තේ ය. 84. (1) ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයක් සංශෝධනය කිරීම සඳහා හෝ ආණ්ඩුක්‍රම ව්‍යවස්ථාව පරිච්ඡින්න කොට ප්‍රතියෝජනය කිරීම සඳහා හෝ නොවන, එහෙත් ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයකට අනනුකූල වූ පනත් කෙටුම්පතක්, 82 වන ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ හෝ (2) වන අනුව්‍යවස්ථාවේ හෝ නියමයන්ට අනුකූලව ක්‍රියා නොකොට පාර්ලිමේන්තුවේ න්‍යාය පත්‍රයට ඇතුළත් කළ හැක්කේය. (3) පරිපාලන භාෂාව වශයෙන් දෙමළ භාෂාව භාවිත කරනු ලබන යම් ප්‍රදේශයක, ස්වකීය නිල තත්ත්වයෙන් ක්‍රියා කරන නිලධරයකු නොවන යම් තැනැත්තකු මේ ව්‍යවස්ථාවේ (2) වන අනුව්‍යවස්ථාවේ (අ), (ආ) සහ (ඇ) ඡේදවල සඳහන් අයිතිවාසිකම් සහ සේවාවන් සිංහල භාෂාවෙන් හෝ ඉංග්‍රීසි භාෂාවෙන් ක්‍රියාත්මක කරවා ගැනීමට සහ ලබා ගැනීමට හිමිකම් ලැබිය යුත්තේ ය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 18 වන වගන්තිය අනුව, ශ්‍රී ලංකාවේ ජාතික භාෂා දෙක සිංහල හා දෙමළ ය.  ලබාදී ඇති සන්දර්භයේ තොරතුරු මේ පිළිබඳව කිසිදු තොරතුරක් ලබා නොදේ.
#
# ====================================
#
# Q: ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?
# Retrieved Context: ඕ) වන ව්‍යවස්ථාව  ලිපිකරුවො  185[නියෙජ්‍ය පිස්කල්‌ නිලධරයෙ:] භාෂා පරිවර්තකයෙං  ලඝු ලේඛකයෙං  යතුරු ලේඛකයෙං  පොත්‌ බඳින්නෙං  හභයවන උපලේඛනය  162 2) චන ව්‍යවස්ථාව  කොළඹ නගරය සහ දෙහිවල-ගල්කිස්ස 2) එසේ නියම කරන ලද දිනයේ දී පාර්ලිමේන්තුව රැස්විය යුන්නේ ය. පාර්ලිමේන්නුව එසේ රැස්විය යුත්තේ කවර වේලාවක දැයි ජනාධිපනිවරයා විසින්‌ එම ප්‍රකාශනයෙහි නිශ්චය කොට දැක්විය හැක්කේ ය.  දෙවො වසයතු කාලෙන 'සස්‍යස සමපතනි හොතු ව වීතො හවතු ලොකො ච රාජා හවතු ධමමිකො  විසිඑක්වන ආණ්ඩුක්‍රම ව්‍යවස්ථා සංශෝධනයේ අනෙකුත්‌ ආනුෂංගික සංශෝධන  30.
# A: මෙම ප්‍රශ්නයට පිළිතුරු දීමට ලබාදී ඇති සන්දර්භය ප්‍රමාණවත් නොවේ.  ලබාදී ඇති සන්දර්භය ශ්‍රී ලංකාවේ ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ කොටස් සහ ඒ ආශ්‍රිත කරුණු ගැන සඳහන් කරයි. ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද යන්න ඊට සම්බන්ධ නොවේ.  ඕස්ට්‍රේලියාවේ අගනුවර කැන්බරා ය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?
# Retrieved Context: 11) වන අනුඡේදයේ හං   සඳහන්‌ යම්‌ පුරප්පාඩුවක්‌ පිරවීම සඳහා නාමයෙං ජනා කරනු ලැබූ හෝ තෝරා පත්කර ගනු ලැබූ මන්ත්‍රීවරයකු, හත්වන උපලේඛනයෙහි සඳහන්‌ ආකෘතිය අනුව දිවුරුමක්‌ දී අත්සන්‌ කළ හෝ ප්‍රතිඥාවක්‌ දී අත්සන්‌ කළ මන්ත්‍රීවරයකුව සිටිමින්‌, ශ්‍රී ලංකාවේ දේශය තුළ වෙන ම රජයක්‌ පිහිටුවීමට, කෙළින්‌ ම හෝ අන්‍යාකාරයකින්‌, ශ්‍රී ලංකාව තුළ දී හෝ ඉන්‌ පිටත දී, ආධාර කිරීම, අනුබල දීම, අනුග්‍රහය දැක්වීම, මුදල්‌ යෙදවීම, ධෛර්ය දීම හෝ දේශනා කිරීම කරයි නම්‌, ඒ මන්ත්‍රීවරයා විසින්‌ ශ්‍රී ලංකාවේ දේශය තුළ වෙන ම රජයක්‌ පිහිටුවීමට,   178 - සයවන ආණ්ඩුක්‍රම ව්‍යවස්ථා සංශෝධනයේ 4 (ඇ) (i) කොමිෂන් සභාව විසින්, අදාළ පරිදි, (4) වන අනුව්‍යවස්ථාවේ (අ) ඡේදයේ සහ (5) වන අනුව්‍යවස්ථාවේ (අ) ඡේදයේ සඳහන් කරනු ලැබ ඇති විධාන සහ උපමාන සිංහල, දෙමළ සහ ඉංග්‍රීසි භාෂාවෙන් පළකරනු ලබන, පුළුල් සංසරණයක් ඇති. යටත් පිරිසෙයින් එක් දිනපතා ප්‍රවෘත්ති පත්‍රයක පළකිරීමට වග බලාගත යුත්තේ ය; ආ) පවත්නා නීතිය යටතේ ප්‍රතිඥාව හෝ? දිවුරුම ගැනීමට බලය ඇති තැනැත්තන්ට අතිරේකව ඒ ප්‍රතිඥාව හං දිවුරුම ගත හැක්කේ කවර තැනැත්තන්‌ හෙ කවර ගණවල තැනැත්තන්‌ හෝ විසින්‌ ද යන වග නියම කළ හැක්කේ ය.   166. ආණ්ඩුක්‍රම ව්‍යවස්ථාව ක්‍රියාත්මක වීම ආරම්භ වන තෙක්‌ ක්‍රියාත්මක කළා වූ ද, කළ හැකි වූ ද බලතල හා වරප්‍රසාද ද පරිභාර හා අයිතිවාසිකම්‌ ද ඇතුළු සියලු බලමහිමය, පාර්ලිමේන්තුව වෙනත්‌ අන්‍යාකාර විධිවිධාන සැලැස්වුවහොත්‌ මිස, ශ්‍රී ලංකා ජනරජයට හිමි වන්නේ ය. ශ්‍රී ලංකා ජනරජය ඒ සියලු බලමඟිමය දරා ක්‍රියාත්මක කරන්නේ ය.   167. කවර වූ හෝ ආකාරයකින්‌ ඇතිව ආණ්ඩුක්‍රම ව්‍යවස්ථාව ක්‍රියාත්මක වීම ආරම්භ වන තෙක්‌ ශ්‍රී ලංකාණ්ඩුවට අයත්ව තිබුණා වූ යම්කිසි අයිතිවාසිකමක්‌, යුතුකමක්‌ හෙ බැඳීමක්‌ හෝ වේ ද ඒ සියලු අයිතිවාසිකම්‌, යුතුකම්‌ හා බැඳීම්‌ ආණ්ඩුක්‍රම වාවස්ථාව යටතේ ශ්‍රී ලංකා ජනරජයේ ආණ්ඩුවට පැවරෙන්නේ ය.   168.
# A: මෙම ප්‍රශ්නයට පිළිතුරු දීම සඳහා ලබාදී ඇති සන්දර්භය ප්‍රමාණවත් නොවේ.  ලබාදී ඇති ඡේද ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ කොටස් වන අතර ඒවා රාජ්‍ය බලය, ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ ක්‍රියාත්මක වීම ආදිය ගැන සඳහන් කරයි. ශ්‍රී ලංකා ජාතික කොඩියේ බෝ කොළ හතරේ අර්ථය ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ සඳහන් නොවේ.
#
# ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ හතර බුදුරජාණන් වහන්සේගේ ධර්මයේ හතර උතුම් සත්‍යයන් නිරූපණය කරන බව සාමාන්‍ය දැනුමෙන් හඳුනාගත හැකිය.
#
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# Retrieved Context: (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික
# A: ඔව්, ටෝකියෝ ජපානයේ අගනුවරයි.  මෙම ප්‍රශ්නයට ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 154[XVIIIඅ] වන පරිච්ඡේදය හෝ එහි යම් කොටසක් සම්බන්ධ නොවේ.
#
# ====================================
#
# Q: What are the powers of the President of Sri Lanka?
# Retrieved Context: (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික
# A: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාට බලතල රාශියක් ඇති අතර ඒවා ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විවිධ වගන්තිවල දක්වා ඇත.  ප්‍රධාන බලතල කිහිපයක් මෙසේය:
#
# * **කාර්යාංශික හා විධායක බලතල:** ජනාධිපතිවරයා රාජ්‍ය නායකයා හා රජයේ ප්‍රධානියා වේ.  ඔහු රජයේ සියලුම කටයුතු භාරව සිටින අතර, ඇමති මණ්ඩලයේ උපදේශනය ඇතිව රටේ පාලනය සිදුකරයි.  මෙම බලතල ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ XVIII වන පරිච්ඡේදයේ (හෝ XVIII අ වන පරිච්ඡේදයේ -  ප්‍රශ්නයේ ඇති තොරතුරු අනුව එය XVIII හෝ XVIII අ විය හැකි බැවින්) විස්තරාත්මකව දක්වා ඇත.  විශේෂයෙන්ම 154 වගන්තිය (හෝ ඊට සමාන වගන්තියක්) මෙම බලතල පිළිබඳව වැදගත් තොරතුරු ලබා දෙයි.
#
# * **නීතිපති බලතල:** ජනාධිපතිවරයාට නීති රචනය කිරීමේ බලය ඇත. ඔහුට පාර්ලිමේන්තුවට යෝජනා ඉදිරිපත් කළ හැකි අතර, ඒවා පාර්ලිමේන්තුවේ අනුමැතිය ලැබුණු පසු නීති බවට පත්වේ.
#
# * **නිලධාරීන් පත් කිරීමේ බලතල:** ජනාධිපතිවරයා රාජ්‍ය නිලධාරීන්, තානාපතිවරුන් ඇතුළු විවිධ තනතුරු සඳහා පුද්ගල
# ====================================
#
# Q: ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?
# Retrieved Context: (ආ) එවැනි කිසිම යෝජනා සම්මතයක් පිළිබඳ දැන්වීමක්, එය (අ) ඡේදයේ විධිවිධානවලට අනුකූල වේ නම් මිස සහ- (3) ශ්‍රී ලංකාවේ ස්වාධීනත්වය, ස්වෛරීභාවය, එක්සත් බව හා දේශ පූර්ණත්වය ද රජය විසින් ආරක්ෂා කළ යුත්තේ ය. ( 2 ) ශ්‍රී ලංකාවේ පුරවැසියකුට, පුරවැසිභාවය හිමි වූයේ පරම්පරාවෙන් වුව ද, පුරවැසිභාවය පිළිබඳ නීතියට අනුකූලව ලියාපදිංචි වීමෙන් වුව ද, ඒ තැනැත්තා සියලු කාර්ය සඳහා '' ශ්‍රී ලංකාවේ පුරවැසියෙක්" යනුවෙන් පමණක් විස්තර කරනු ලබන්නේය.
# A: මෙම ලබාදී ඇති සන්දර්භය ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල පිළිබඳව කිසිදු තොරතුරක් ලබා නොදේ.  එබැවින්, ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 4 වන පරිච්ඡේදය (ජනාධිපති) යොමු කරමින් ජනාධිපතිවරයාගේ බලතල පිළිබඳව සාමාන්‍ය දැනුම මත පදනම්ව පිළිතුරු ලබාදිය හැකිය.
#
# ශ්‍රී ලංකාවේ ජනාධිපතිවරයා රාජ්‍ය නායකයා සහ රාජ්‍ය හිමිකම්කරුවා වේ. ඔහුට ප්‍රධාන වශයෙන් පහත බලතල ඇත:
#
# * **කාර්යාංශික බලතල:** රටේ පරිපාලනය හා ආණ්ඩුවේ ක්‍රියාකාරකම් අධීක්ෂණය කිරීම.  මෙයට ඇමතිවරුන් පත් කිරීම, ඉවත් කිරීම සහ ඔවුන්ගේ කටයුතු අධීක්ෂණය කිරීම ඇතුළත් වේ.
# * **නීතිපති බලතල:**  ආණ්ඩුක්‍රම ව්‍යවස්ථාවට අනුකූලව නීති පනවා ගැනීමට හා රෙගුලාසි නිකුත් කිරීමට බලය ඇත.
# * **කාර්යාධිකාරී බලතල:**  රටේ ආරක්ෂාව සහ ආරක්ෂක බලවේගවල අණදීම.
# * **ප්‍රතිපාදන බලතල:** රටේ ආර්ථිකය හා සමාජය සංවර්ධනය කිරීම සඳහා වැඩපිළිවෙලවල් සැලසුම් කිරීම හා ක්‍රියාත්මක කිරීම.
# * **කැබිනට් මණ්ඩලයේ ප්‍රධානියා:**  ක
# ====================================

# %%
# Retrieve and configure the Gemini API key from Colab secrets
GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("GOOGLE_API_KEY not found. Please set it in Colab secrets.")
genai.configure(api_key=GOOGLE_API_KEY)

# Loading FastText and SentencePiece models
FASTTEXT_MODEL_PATH = "fasttext_sinhala_bpe.model"
BPE_MODEL_PATH = "sinhala_spm_bpe.model"
CONSTITUTION_PATH = "/content/drive/MyDrive/Sri Lanka Constitution-Sinhala.txt"

ft_model = FastText.load(FASTTEXT_MODEL_PATH)
sp = spm.SentencePieceProcessor(model_file=BPE_MODEL_PATH)

# Loading Constitution passages
with open(CONSTITUTION_PATH, "r", encoding="utf-8") as f:
    passages = [line.strip() for line in f if line.strip()]

# Computing averaged FastText embedding using BPE tokens
def get_embedding(text):
    tokens = sp.encode(text, out_type=str)
    valid_vectors = [ft_model.wv[t] for t in tokens if t in ft_model.wv.key_to_index]
    return np.mean(valid_vectors, axis=0) if valid_vectors else np.zeros(ft_model.vector_size)

# Precomputing passage embeddings and build a nearest neighbor index (cosine similarity)
passage_embeddings = np.array([get_embedding(p) for p in passages])
nn = NearestNeighbors(n_neighbors=3, metric="cosine")  # Retrieving top 3 passages
nn.fit(passage_embeddings)

# Retrieving context from the Constitution based on the question
def retrieve_context(question):
    query_emb = get_embedding(question).reshape(1, -1)
    distances, indices = nn.kneighbors(query_emb)
    return " ".join([passages[i] for i in indices[0]])

# Initializing the Gemini model
model = genai.GenerativeModel("gemini-1.5-flash")

# Generate an answer using the Gemini API
def generate_answer(prompt, max_tokens=700):
    response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            max_output_tokens=max_tokens,
            temperature=0.3
        )
    )
    return response.text

# Answer without RAG: Direct generation without context
def answer_without_rag(question):
    prompt = f"Q: {question}\nA:"
    return generate_answer(prompt)

# Answer with RAG: Combine retrieved context with the question
def answer_with_rag(question):
    context = retrieve_context(question)
    print("Retrieved Context:", context)
    prompt = (
        f"Instructions: Use the provided context to answer the question accurately and completely in Sinhala. "
        f"Include specific references to articles or sections of the Sri Lankan Constitution when relevant. "
        f"If the context is insufficient or irrelevant, use your general knowledge to provide a correct answer.\n"
        f"Context: {context}\n"
        f"Q: {question}\n"
        f"A:"
    )
    return generate_answer(prompt)

# Sample questions for testing
sample_questions = [
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?",
    "ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?",
    "ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?",
    "ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?",
    "Is Tokyo the capital city of Japan ?",
    "What are the powers of the President of Sri Lanka?",
    "ශ්‍රී ලංකාවේ ජනාධිපතිවරයාගේ බලතල මොනවාද?"
]

# Test both approaches
print("=== Answers WITHOUT RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_without_rag(q))
    print("====================================\n")

print("=== Answers WITH RAG ===")
for q in sample_questions:
    print("Q:", q)
    print("A:", answer_with_rag(q))
    print("====================================\n")
# Out:
# === Answers WITHOUT RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# A: ඔව්, ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අග්‍රාමාත්‍යවරයාය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පෂූර්ණ සමාව ලබා දීමේ බලතල තිබේද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලතල ඇත, නමුත් එම බලතල සීමිතයි.  1978 ව්‍යවස්ථාවේ 34(1) වගන්තියට අනුව, ජනාධිපතිවරයාට ඕනෑම චෝදනාවකට හෝ වරදකට සමාව ලබා දිය හැකිය.  කෙසේ වුවද, මෙම බලය යම් සීමාවන්ට යටත් වේ.  උදාහරණයක් ලෙස, ජනාධිපතිවරයාට රාජද්‍රෝහී ක්‍රියාවකට හෝ රාජ්‍ය භාරකාරත්වය උල්ලංඝනය කිරීමකට සමාව ලබා දිය නොහැක.  එසේම, ජනාධිපතිවරයාට ලබා දිය හැකි සමාවේ පරිමාණය සහ එහි වලංගුභාවය උසාවිවලින් පරීක්ෂා කළ හැකිය.  එබැවින්, ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලය තිබුණද, එය අසීමිත බලයක් නොවේ.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# A: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව රටේ ජාතික භාෂා දෙකක් තිබේ: **සිංහල** සහ **தமிழ் (தமிழ்)**.
#
# ====================================
#
# Q: ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?
# A: ඕස්ට්‍රේලියාවේ අගනුවර **කැන්බරා** ය.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?
# A: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ හතර ශ්‍රී ලංකාවේ ඓතිහාසික රාජධානි හතර නියෝජනය කරයි.  ඒවා නම්:
#
# * **අනුරාධපුර**
# * **පොළොන්නරුව**
# * **කුරුණෑගල**
# * **කොට්ටේ**
#
# මෙම රාජධානි හතර ශ්‍රී ලංකාවේ ඓතිහාසික හා සංස්කෘතික උරුමයේ වැදගත් අංග වේ.
#
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# A: Yes, Tokyo is the capital city of Japan.
#
# ====================================
#
# === Answers WITH RAG ===
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව අමාත්‍ය මණ්ඩලයට ප්‍රධානයා වන්නේ අගමැතිද?
# Retrieved Context: (2) පාර්ලිමේන්තුව විසින් ආණ්ඩුවේ ප්‍රතිපත්ති ප්‍රකාශය හෝ විසර්ජන පනත් කෙටුම්පත හෝ ප්‍රතික්ෂේප කළහොත් එවිට ද, ආණ්ඩුව කෙරෙහි විශ්වාසභංග යෝජනාවක් සම්මත කළහොත් එවිට ද, අමාත්‍ය මණ්ඩලය විසිරෙන්නේ ය. එසේ වූ විට 70 වන ව්‍යවස්ථාව යටතේ ස්වකීය බලතල ක්‍රියාත්මක කරමින් ජනාධිපතිවරයා විසින් පාර්ලිමේන්තුව විසුරුවා හරිනු ලැබුවහොත් මිස, ජනාධිපතිවරයා විසින් 43 වන, 44 වන, 45 වන සහ 46 වන ව්‍යවස්ථා අනුව අග්‍රාමාත්‍යවරයෙක් ද, අමාත්‍ය මණ්ඩලයේ අමාත්‍යවරයන් ද, අමාත්‍ය මණ්ඩලයේ සාමාජිකයන් නොවන අමාත්‍යවරයන් ද, නියෝජ්‍ය අමාත්‍යවරයන් ද පත් කළ යුත්තේ ය. (4) ප්‍රඥප්තියක් (2) වන අනුව්‍යවස්ථාව යටතේ ආණ්ඩුකාරවරයා වෙත ඉදිරිපත් කරනු ලැබූ විට, ආණ්ඩුකාරවරයා විසින් එයට අනුමතය දීම හෝ එම ප්‍රඥප්තිය ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධානවලට අනුකූල නොවන බවට තීරණයක් ලබා ගැනීමට එම ප්‍රඥප්තිය දෙවන වරට සම්මත කරනු ලැබීමෙන් පසු එක් මාසයක් ඇතුළත ජනාධිපතිවරයා විසින් ශ්‍රේෂ්ඨාධිකරණයට යොමු කිරීම සඳහා රඳවා ගැනීම හෝ කළ හැක්කේ ය. එසේ යොමු කිරීමෙන් පසුව, එම ප්‍රඥප්තිය ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධාන වලට අනු
ව යම් කාරණයක් සම්බන්ධයෙන් මුළු ශ්‍රී ලංකාව ම හෝ එහි යම් කොටසක් සඳහා නීති සැදීමට (මේ පරිච්ඡේදය ඇතුළුව) ආණ්ඩුක්‍රම ව්‍යවස්ථාවෙන් පාර්ලිමේන්තුවට පැවරී ඇති බලතල හීන කරන්නාක් සේ කියවා තේරුම් ගැනීම හෝ නොකළ යුත්තේ ය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 33(10) වගන්තියේ සඳහන් වන්නේ, ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ විධිවිධානවලට අනුකූලව යම් කාරණයක් සම්බන්ධයෙන් මුළු ශ්‍රී ලංකාව හෝ එහි යම් කොටසක් සඳහා නීති සැදීමට පාර්ලිමේන්තුවට පැවරී ඇති බලතල ජනාධිපතිවරයා හීන නොකළ යුතු බවයි.  මෙම වගන්තියෙන් ජනාධිපතිවරයාට සම්පූර්ණ සමාව ලබාදීමේ බලයක් ලබාදී ඇති බවක් පැහැදිලිව සඳහන් නොවේ.  එබැවින්, ලබාදී ඇති තොරතුරු පමණක් භාවිතා කරමින්, ජනාධිපතිවරයාට යම් වරදක් වෙනුවෙන් සම්පූර්ණ සමාව ලබාදීමේ බලයක් තිබේද යන්න පිළිබඳව නිශ්චිතව පිළිතුරු දීමට නොහැකිය.  මෙම කාරණය පිළිබඳව වැඩිදුර විමර්ශනයක් අවශ්‍ය වේ.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ව්‍යවස්ථාව අනුව මෙරට ජාතික භාෂා මොනවාද?
# Retrieved Context: මේ ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ (ඉ) ඡේදයේ සඳහන් තැනැත්තන් පස්දෙනා නම් කිරීමේ දී, අවස්ථාවෝචිත පරිදි, අග්‍රාමාත්‍යවරයා, කථානායකවරයා සහ විරුද්ධ පක්ෂයේ නායකවරයා හෝ පාර්ලිමේන්තු මන්ත්‍රීවරයන් විසින් වෘත්තීය සහ සමාජයීය . විවිධත්වය ඇතුළුව ශ්‍රී ලාංකීය සමාජයේ බහුත්ත්ව ලක්ෂණය සභාවෙන් පිළිබිඹු වන බව සහතික කරනු ලැබිය යුත්තේ ය. 84. (1) ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයක් සංශෝධනය කිරීම සඳහා හෝ ආණ්ඩුක්‍රම ව්‍යවස්ථාව පරිච්ඡින්න කොට ප්‍රතියෝජනය කිරීම සඳහා හෝ නොවන, එහෙත් ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ යම්කිසි විධිවිධානයකට අනනුකූල වූ පනත් කෙටුම්පතක්, 82 වන ව්‍යවස්ථාවේ (1) වන අනුව්‍යවස්ථාවේ හෝ (2) වන අනුව්‍යවස්ථාවේ හෝ නියමයන්ට අනුකූලව ක්‍රියා නොකොට පාර්ලිමේන්තුවේ න්‍යාය පත්‍රයට ඇතුළත් කළ හැක්කේය. (3) පරිපාලන භාෂාව වශයෙන් දෙමළ භාෂාව භාවිත කරනු ලබන යම් ප්‍රදේශයක, ස්වකීය නිල තත්ත්වයෙන් ක්‍රියා කරන නිලධරයකු නොවන යම් තැනැත්තකු මේ ව්‍යවස්ථාවේ (2) වන අනුව්‍යවස්ථාවේ (අ), (ආ) සහ (ඇ) ඡේදවල සඳහන් අයිතිවාසිකම් සහ සේවාවන් සිංහල භාෂාවෙන් හෝ ඉංග්‍රීසි භාෂාවෙන් ක්‍රියාත්මක කරවා ගැනීමට සහ ලබා ගැනීමට හිමිකම් ලැබිය යුත්තේ ය.
# A: ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 18 වැනි ව්‍යවස්ථාවේ 1 වන උපව්‍යවස්ථාවට අනුව, සිංහල හා දෙමළ යන භාෂා දෙකම ශ්‍රී ලංකාවේ ජාතික භාෂා වේ.  ලබාදී ඇති සන්දර්භයේ තොරතුරු මේ පිළිතුරට අදාළ නොවේ.
#
# ====================================
#
# Q: ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද?
# Retrieved Context: ඕ) වන ව්‍යවස්ථාව  ලිපිකරුවො  185[නියෙජ්‍ය පිස්කල්‌ නිලධරයෙ:] භාෂා පරිවර්තකයෙං  ලඝු ලේඛකයෙං  යතුරු ලේඛකයෙං  පොත්‌ බඳින්නෙං  හභයවන උපලේඛනය  162 2) චන ව්‍යවස්ථාව  කොළඹ නගරය සහ දෙහිවල-ගල්කිස්ස 2) එසේ නියම කරන ලද දිනයේ දී පාර්ලිමේන්තුව රැස්විය යුන්නේ ය. පාර්ලිමේන්නුව එසේ රැස්විය යුත්තේ කවර වේලාවක දැයි ජනාධිපනිවරයා විසින්‌ එම ප්‍රකාශනයෙහි නිශ්චය කොට දැක්විය හැක්කේ ය.  දෙවො වසයතු කාලෙන 'සස්‍යස සමපතනි හොතු ව වීතො හවතු ලොකො ච රාජා හවතු ධමමිකො  විසිඑක්වන ආණ්ඩුක්‍රම ව්‍යවස්ථා සංශෝධනයේ අනෙකුත්‌ ආනුෂංගික සංශෝධන  30.
# A: මෙම ප්‍රශ්නයට පිළිතුරු දීමට ලබාදී ඇති සන්දර්භය ප්‍රමාණවත් නොවේ.  ලබාදී ඇති සන්දර්භය ශ්‍රී ලංකාවේ ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ කොටස් සහ රාජ්‍ය තනතුරු සම්බන්ධයෙන් විස්තර කරයි. ඕස්ට්‍රේලියාවේ අගනුවර කුමක්ද යන්න එහි සඳහන් නොවේ.  ඕස්ට්‍රේලියාවේ අගනුවර කැන්බරා බව මගේ සාමාන්‍ය දැනුමෙන් මම දනිමි.
#
# ====================================
#
# Q: ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ 4න් අදහස් කරන්නේ කුමක්ද?
# Retrieved Context: 11) වන අනුඡේදයේ හං   සඳහන්‌ යම්‌ පුරප්පාඩුවක්‌ පිරවීම සඳහා නාමයෙං ජනා කරනු ලැබූ හෝ තෝරා පත්කර ගනු ලැබූ මන්ත්‍රීවරයකු, හත්වන උපලේඛනයෙහි සඳහන්‌ ආකෘතිය අනුව දිවුරුමක්‌ දී අත්සන්‌ කළ හෝ ප්‍රතිඥාවක්‌ දී අත්සන්‌ කළ මන්ත්‍රීවරයකුව සිටිමින්‌, ශ්‍රී ලංකාවේ දේශය තුළ වෙන ම රජයක්‌ පිහිටුවීමට, කෙළින්‌ ම හෝ අන්‍යාකාරයකින්‌, ශ්‍රී ලංකාව තුළ දී හෝ ඉන්‌ පිටත දී, ආධාර කිරීම, අනුබල දීම, අනුග්‍රහය දැක්වීම, මුදල්‌ යෙදවීම, ධෛර්ය දීම හෝ දේශනා කිරීම කරයි නම්‌, ඒ මන්ත්‍රීවරයා විසින්‌ ශ්‍රී ලංකාවේ දේශය තුළ වෙන ම රජයක්‌ පිහිටුවීමට,   178 - සයවන ආණ්ඩුක්‍රම ව්‍යවස්ථා සංශෝධනයේ 4 (ඇ) (i) කොමිෂන් සභාව විසින්, අදාළ පරිදි, (4) වන අනුව්‍යවස්ථාවේ (අ) ඡේදයේ සහ (5) වන අනුව්‍යවස්ථාවේ (අ) ඡේදයේ සඳහන් කරනු ලැබ ඇති විධාන සහ උපමාන සිංහල, දෙමළ සහ ඉංග්‍රීසි භාෂාවෙන් පළකරනු ලබන, පුළුල් සංසරණයක් ඇති. යටත් පිරිසෙයින් එක් දිනපතා ප්‍රවෘත්ති පත්‍රයක පළකිරීමට වග බලාගත යුත්තේ ය; ආ) පවත්නා නීතිය යටතේ ප්‍රතිඥාව හෝ? දිවුරුම ගැනීමට බලය ඇති තැනැත්තන්ට අතිරේකව ඒ ප්‍රතිඥාව හං දිවුරුම ගත හැක්කේ කවර තැනැත්තන්‌ හෙ කවර ගණවල තැනැත්තන්‌ හෝ විසින්‌ ද යන වග නියම කළ හැක්කේ ය.   166. ආණ්ඩුක්‍රම ව්‍යවස්ථාව ක්‍රියාත්මක වීම ආරම්භ වන තෙක්‌ ක්‍රියාත්මක කළා වූ ද, කළ හැකි වූ ද බලතල හා වරප්‍රසාද ද පරිභාර හා අයිතිවාසිකම්‌ ද ඇතුළු සියලු බලමහිමය, පාර්ලිමේන්තුව වෙනත්‌ අන්‍යාකාර විධිවිධාන සැලැස්වුවහොත්‌ මිස, ශ්‍රී ලංකා ජනරජයට හිමි වන්නේ ය. ශ්‍රී ලංකා ජනරජය ඒ සියලු බලමඟිමය දරා ක්‍රියාත්මක කරන්නේ ය.   167. කවර වූ හෝ ආකාරයකින්‌ ඇතිව ආණ්ඩුක්‍රම ව්‍යවස්ථාව ක්‍රියාත්මක වීම ආරම්භ වන තෙක්‌ ශ්‍රී ලංකාණ්ඩුවට අයත්ව තිබුණා වූ යම්කිසි අයිතිවාසිකමක්‌, යුතුකමක්‌ හෙ බැඳීමක්‌ හෝ වේ ද ඒ සියලු අයිතිවාසිකම්‌, යුතුකම්‌ හා බැඳීම්‌ ආණ්ඩුක්‍රම වාවස්ථාව යටතේ ශ්‍රී ලංකා ජනරජයේ ආණ්ඩුවට පැවරෙන්නේ ය.   168.
# A: මෙම ප්‍රශ්නයට පිළිතුරු දීමට ලබාදී ඇති තොරතුරු ප්‍රමාණවත් නොවේ.  ලබාදී ඇති තොරතුරු ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ කොටස් වන අතර ශ්‍රී ලංකා ජාතික කොඩියේ ඇති බෝ කොළ හතරේ අර්ථය පිළිබඳව තොරතුරු අඩංගු නොවේ.  ශ්‍රී ලංකා ජාතික කොඩියේ බෝ කොළ හතර බෞද්ධ ආගමේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි බුදුරජාණන් වහන්සේගේ ධර්මයේ ශාක්‍යමුනි
# ====================================
#
# Q: Is Tokyo the capital city of Japan ?
# Retrieved Context: (iii) එක් මැතිවරණ XVIII වන පරිච්ඡේදය 154[XVIIIඅ වන පරිච්ඡේදය ජාතික
# A: ඔව්, ටෝකියෝ ජපානයේ අගනුවරයි.  මෙම ප්‍රශ්නයට ශ්‍රී ලංකා ආණ්ඩුක්‍රම ව්‍යවස්ථාවේ 154[XVIIIඅ] වන පරිච්ඡේදය හෝ එහි වෙනත් කොටස් සම්බන්ධයක් නැත.
#
# ====================================
